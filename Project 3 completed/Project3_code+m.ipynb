# %% [markdown]
# # Team George Washington Carver Presents: Project 3 #

# %% [markdown]
# # Food Demand in Guatemala #

# %% [markdown]
# ##### For context of our team's code and presentation overall, Guatemala is a country in Central America, and shares its border with the south of Mexico. It has high rates of climate related disasters and deeply divided socioeconomic classes, where poverty is concentrated in the ​​​​Noroccidente region. As a result, a large portion of Guatemala faces malnutrition and food insecurity.
# #### We hope you are find the contents of food demand in Guatemala in our code interesting!

# %% [markdown]
# # [0] Installations & Imports

# %%
# !pip install python-gnupg 
# !pip install eep153_tools --upgrade
# !pip install cufflinks
# %pip install CFEDemands
# Out:
# ...
#   Using cached python_gnupg-0.5.2-py2.py3-none-any.whl (20 kB)
# ...
#   Using cached eep153_tools-0.12.4-py2.py3-none-any.whl (4.9 kB)
# ...
#   Using cached cufflinks-0.17.3-py3-none-any.whl
# ...
#   Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# ...
#   Using cached CFEDemands-0.6.1-py2.py3-none-any.whl (45 kB)
# ...
#   Using cached dvc-3.49.0-py3-none-any.whl (450 kB)
# ...
#   Using cached xarray-2024.3.0-py3-none-any.whl (1.1 MB)
# ...
#   Using cached ray-2.10.0-cp39-cp39-manylinux2014_x86_64.whl (65.1 MB)
# ...
#   Using cached ConsumerDemands-0.4.2.dev0-py2.py3-none-any.whl (12 kB)
# ...
#   Using cached configobj-5.0.8-py2.py3-none-any.whl (36 kB)
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl (154 kB)
# ...
#   Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# ...
#   Using cached dvc_objects-5.1.0-py3-none-any.whl (33 kB)
# ...
#   Using cached iterative_telemetry-0.0.8-py3-none-any.whl (10 kB)
# ...
#   Using cached dvc_task-0.4.0-py3-none-any.whl (21 kB)
# ...
#   Using cached kombu-5.3.6-py3-none-any.whl (200 kB)
# ...

# %%
import pandas as pd
import numpy as np
from eep153_tools.sheets import read_sheets

# %% [markdown]
# # [1] Data Input

# %% [markdown]
# #### We used the information in the provided Guatemala spreadsheet in EdStem, then edited it in order to simplify down to the 8 different regions in Guatemala with their demand (in pounds) for each food item. It is curated to display the food items that are commonly consumed in Guatemala. This spreadsheet is converted into a csv file and can be found in our repository!

# %% [markdown]
# ##### Edstem Guatemala Source: https://docs.google.com/spreadsheets/d/1YupX14TogoubSrlHtG9OgfBdKUhsss29L63mcNDNCUo/

# %%
Guatemala = '1YupX14TogoubSrlHtG9OgfBdKUhsss29L63mcNDNCUo'

# %%
x = read_sheets(Guatemala,sheet='Food Expenditures')
x.columns.name = 'j'
x
# Out:
# j        i     t              m  Cooking Oil  Water (bottle)  Avocado  \
# 0        1  2000  Metropolitana          7.5            20.0      5.0
# 1       10  2000  Metropolitana         15.0            15.0     30.0
# 2      100  2000  Metropolitana         13.0            10.5      NaN
# 3     1000  2000        Central          9.5            10.0      NaN
# 4     1001  2000        Central         10.0            20.0      5.0
# ...    ...   ...            ...          ...             ...      ...
# 7252   995  2000        Central          NaN             NaN      NaN
# 7253   996  2000        Central         13.0            12.0      NaN
# 7254   997  2000        Central          1.5             NaN      NaN
# 7255   998  2000        Central         16.0            37.5      4.0
# 7256   999  2000        Central         16.0             NaN     12.0
#
# j     Mineral Water  Garlic  Mushrooms  Celery  ...   Tea  Tomatoes  \
# ...

# %% [markdown]
# ### [1.1] data classification

# %%
p = pd.read_csv('Team George Washington Guatemala - Food Prices.csv')
p = p.drop(p.columns[1], axis=1)
p = p.T
p = p.set_index(p.iloc[:,0])
p.columns = p.iloc[0]
p = p.drop(p.columns[0], axis=1).iloc[1:]
p
# Out:
# j              Cooking Oil Water (bottle)      Avocado Mineral Water  \
# 0
# Central        5.010737261   0.4545454447  1.865671595    2.75077949
# Metropolitana  5.368647065   0.2405002401  3.544776031   2.731270434
# Noroccidente   4.545454447   0.2405002401  1.492537276   3.209242684
# Nororiente     4.563468033   0.2645502553  3.731343191   3.209242684
# Norte          5.368647065   0.2405002401  1.492537276   3.209242684
# Peten          4.999999892   0.3006252964  1.492537276    3.85109122
# Suroccidente    3.86363628   0.2457002404  1.492537276   3.209242684
# Suroriente     5.368647065   0.2886002882  2.985074553   3.209242684
#
# j                   Garlic Mushrooms       Celery         Rice Peas  \
# 0
# Central         4.54545457        12  2.262489754          2.5    3
# Metropolitana   4.54545457        26            3          2.5    6
# Noroccidente    4.54545457         7  2.265861026         2.25  2.5
# ...

# %%
d = read_sheets(Guatemala,sheet="Household Characteristics")
d.columns.name = 'k'

# x may have duplicate columns
x = x.T.groupby('j').sum().T
x = x.replace(0,np.nan) # Replace zeros with missing

# Take logs of expenditures; call this y
y = np.log(x.set_index(['i','t','m']))

d.set_index(['i','t','m'],inplace=True)
# Out:
# /tmp/ipykernel_157/3968031923.py:6: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   x = x.replace(0,np.nan) # Replace zeros with missing

# %%
d.head()
# Out:
# k                     Males 00-03  Females 00-03  Males 04-08  Females 04-08  \
# i t    m
# 1 2000 Metropolitana            0              1            0              0
# 2 2000 Metropolitana            0              0            0              0
# 3 2000 Metropolitana            0              0            0              0
# 4 2000 Metropolitana            0              0            0              0
# 5 2000 Metropolitana            0              0            1              0
#
# k                     Males 09-13  Females 09-13  Males 14-18  Females 14-18  \
# i t    m
# 1 2000 Metropolitana            0              0            0              0
# 2 2000 Metropolitana            0              0            0              0
# 3 2000 Metropolitana            2              0            0              0
# 4 2000 Metropolitana            0              0            0              0
# 5 2000 Metropolitana            0              0            0              0
#
# ...

# %%
y.head()
# Out:
# j                         Avocado   Bananas     Beans      Beef  \
# i    t    m
# 1    2000 Metropolitana  1.609438  2.639057  1.609438  5.828946
# 10   2000 Metropolitana  3.401197  3.583519  2.302585  5.762051
# 100  2000 Metropolitana       NaN  2.833213       NaN  4.499810
# 1000 2000 Central             NaN  3.091042  2.014903  5.075174
# 1001 2000 Central        1.609438  2.890372  2.014903  4.927254
#
# j                        Beef Entrails      Beer     Beets  Bread (french)  \
# i    t    m
# 1    2000 Metropolitana            NaN       NaN       NaN        3.401197
# 10   2000 Metropolitana       3.401197  3.178054       NaN        4.430817
# 100  2000 Metropolitana       2.772589       NaN  1.504077        1.791759
# 1000 2000 Central                  NaN       NaN       NaN        3.401197
# 1001 2000 Central             2.484907       NaN  1.321756        3.113515
#
# j                        Bread (sliced)  Bread (sweet)  ...  Tomato Sauce  \
# ...

# %% [markdown]
# # [2] Estimation

# %%
y = y.stack()

d = d.stack()

# Check that indices are in right places!
assert y.index.names == ['i','t','m','j']
assert d.index.names == ['i','t','m','k']

# %%
from cfe import Regression
result = Regression(y=y,d=d)

# %%
result.predicted_expenditures()
# Out:
# i     t     m              j
# 1     2000  Metropolitana  Avocado             7.131134
#                            Bananas            16.368000
#                            Beans               9.351316
#                            Beef              102.055889
#                            Beef Entrails      13.977229
#                                                 ...
# 7276  2000  Suroriente     Tostadas            8.796111
#                            Water (bottle)      9.580927
#                            Watermelon          7.935121
#                            Wheat Flour         4.943983
#                            Yucca               3.456677
# Length: 515736, dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-dark')
plt.figure(figsize=(8, 6))

df = pd.DataFrame({'y':y,'yhat':result.get_predicted_log_expenditures()})
df.plot.scatter(x='yhat',y='y',color='#245c39')

plt.xlabel('predicted log expenditures')
plt.ylabel('actual log expenditures')
plt.savefig('scatter_plot.png', transparent=True)
# Out:
# /tmp/ipykernel_157/1199289293.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-dark')

# %% [markdown]
# # [3] Parameters

# %% [markdown]
# #### Relative Income Elasticity

# %% [markdown]
# Below, we created a plot with different confidence intervals.

# %%
ax = result.graph_beta()
plt.savefig('graph_beta.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ###### Values of Beta Coefficients with corresponding elasticities

# %%
result.get_beta()
# Out:
# j
# Avocado           1.208501
# Bananas           1.557200
# Beans             0.620259
# Beef              1.447294
# Beef Entrails     0.797537
#                     ...
# Tostadas          1.018462
# Water (bottle)    0.908400
# Watermelon        0.955107
# Wheat Flour       1.010762
# Yucca             0.829638
# Name: beta, Length: 76, dtype: float64

# %% [markdown]
# ###### A higher income elasticity coefficient beta indicates that the demand for the good is more sensitive to changes in income, while a lower coefficient suggests less sensitivity. We can draw the conclusion from this that people in Guatemala consume Maize, Tortillas, Salt, Beans, and other foods that have low income elasticity as a necessary daily diet, while buy Ice cream, Juice, and Bananas that have high income elasticity only when their income level is high enough. This shows that if prices are higher for goods like ice cream, juice, and bananas, then Guatemalans will generally stop buying or reduce their demands for it. On the other hand, maize, tortillas, and salt are staples and they will remain demanding it.

# %% [markdown]
# ### Demand and Household Composition

# %%
result.get_gamma()
# Out:
# k               Males 00-03  Females 00-03  Males 04-08  Females 04-08  \
# j
# Avocado           -0.113787      -0.154271    -0.052185      -0.075399
# Bananas           -0.132104      -0.160179    -0.078016      -0.077231
# Beans              0.008229      -0.012377     0.041968       0.015699
# Beef              -0.175282      -0.143385    -0.095217      -0.083608
# Beef Entrails      0.040482      -0.030306    -0.046508       0.028354
# ...                     ...            ...          ...            ...
# Tostadas          -0.222922      -0.109068    -0.134434      -0.059171
# Water (bottle)     0.006573      -0.005665     0.001005      -0.018112
# Watermelon        -0.004826      -0.041615     0.003598      -0.073471
# Wheat Flour        0.083686       0.046527     0.035809      -0.090453
# Yucca              0.040381      -0.037981    -0.018022      -0.004429
#
# k               Males 09-13  Females 09-13  Males 14-18  Females 14-18  \
# j
# ...

# %% [markdown]
# # [4] Welfare

# %%
import matplotlib.pyplot as plt
ax = result.get_w().plot.hist(bins=100, density=True, color='#9eb467')
result.get_w().plot.kde(ax=ax, color='#3c4634')
plt.savefig('histogram_plot.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# ## Demand and Utility

# %% [markdown]
# #### Budgets

# %%
import numpy as np

xhat = result.predicted_expenditures()

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# %% [markdown]
# ## Reference Prices

# %%
p_numeric = p.map(pd.to_numeric, errors='coerce')
pbar = p_numeric.mean()

# %%
pbar = pbar[result.beta.index] # Only use prices for goods we can estimate

#Finally, define a function to change a single price in the vector $p$:
def my_prices(p0,p=pbar,j='Beans'):
    """
    Change price of jth good to p0, holding other prices fixed.
    """
    p = p.copy()
    p.loc[j] = p0
    return p

# %% [markdown]
# ## Demand as a function of prices

# %% [markdown]
# #### We define a demand_curve function to visualize demand curve for different goods.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
  
def demand_curve(use):
    # Vary prices from 50% to 200% of reference.
    scale = np.linspace(.5,2,20)
    
    # Demand for Beans for household at median budget
    plt.plot([result.demands(xref,my_prices(pbar[use]*s,pbar,use))[use] for s in scale],scale)
    
    # Demand for Beans for household at 25% percentile
    plt.plot([result.demands(xbar.quantile(0.25),my_prices(pbar[use]*s,pbar,use))[use] for s in scale],scale)
    
    # Demand for Beans for household at 75% percentile
    plt.plot([result.demands(xbar.quantile(0.75),my_prices(pbar[use]*s,pbar,use))[use] for s in scale],scale)

    plt.ylabel(f"Price (relative to base of {pbar[use]:.2f})")
    plt.xlabel(f"Quantities of {use} Demanded")

# %%
demand_curve('Beans')
plt.savefig('beans.png', transparent = True)

# %%
demand_curve('Chocolate')
plt.savefig('chocolate.png', transparent = True)

# %% [markdown]
# # [5] Engel Curves: How Demand Changes with Budget

# %%
fig,ax = plt.subplots()
scale = np.linspace(0.1, 2, 100)
ax.plot(np.log(scale*xref),[result.expenditures(s*xref,pbar)/(s*xref) for s in scale])
ax.set_xlabel(f'log budget (relative to base of {xref:.0f}')
ax.set_ylabel(f'Expenditure share')
ax.set_title('Engel Curves')
plt.savefig('Engel Curves.png', transparent = True)

# %% [markdown]
# ## In order to see more details in this graph, we created an interactive plot, where you can click on the different foods to turn off the corresponding line plot

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.29.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
index = pd.Index(np.log(scale * xref),name='log budget')
df = pd.DataFrame([result.expenditures(s*xref,pbar)/(s*xref) for s in scale],index=index)

# %%
df.iplot()

# %% [markdown]
# # [6] Indirect Utility

# %%
fig,ax = plt.subplots()

ax.plot(scale*xref,[result.indirect_utility(s*xref,pbar) for s in scale])
ax.set_xlabel(f'Indirect Utility (Budget relative to base of {xref:.0f}')
ax.set_ylabel(f'Utility')
ax.set_title('Indirect Utility Function')
plt.savefig('indirect_utility_plot.png', transparent=True, bbox_inches='tight')

# %% [markdown]
# # [7] nutritional content

# %% [markdown]
# ##### The beta coefficients determine how income elastic different foods are, where higher values are more elastic. With higher elasticity, their demand for the food is more price responsive if prices change for that food.

# %%
df0 = result.get_beta().to_frame()
df0
# Out:
#                     beta
# j
# Avocado         1.208501
# Bananas         1.557200
# Beans           0.620259
# Beef            1.447294
# Beef Entrails   0.797537
# ...                  ...
# Tostadas        1.018462
# Water (bottle)  0.908400
# Watermelon      0.955107
# Wheat Flour     1.010762
# Yucca           0.829638
#
# [76 rows x 1 columns]

# %% [markdown]
# ### Find FDC code for each food

# %%
import pandas as pd
import requests

def get_fdc_code(food_name, api_key):
    search_url = "https://api.nal.usda.gov/fdc/v1/foods/search"
    params = {
        "query": food_name,
        "api_key": api_key  # Corrected parameter name here
    }
    response = requests.get(search_url, params=params)
    if response.status_code == 200:
        data = response.json()
        if data['foods']:
            return data['foods'][0]['fdcId']
        else:
            return None
    else:
        print(f"Failed to retrieve data for {food_name}. Response: {response.text}")
        return None
apikey = "Z4ehkkMbO1DlcukePiecqfxU55sRATGnDJHItl5B"
df0['FDC'] = df0.index.map(lambda x: get_fdc_code(x, apikey))
df0.head()
# Out:
#                    beta        FDC
# j
# Avocado        1.208501  2345765.0
# Bananas        1.557200   173945.0
# Beans          0.620259  2169653.0
# Beef           1.447294  2038522.0
# Beef Entrails  0.797537  2341787.0

# %%
df0.fillna(0)
df0['FDC'] = df0['FDC'].astype('Int64')
df0['FDC'] = df0['FDC'].astype('str')
df0
# Out:
#                     beta      FDC
# j
# Avocado         1.208501  2345765
# Bananas         1.557200   173945
# Beans           0.620259  2169653
# Beef            1.447294  2038522
# Beef Entrails   0.797537  2341787
# ...                  ...      ...
# Tostadas        1.018462  2013402
# Water (bottle)  0.908400  2346284
# Watermelon      0.955107  2193119
# Wheat Flour     1.010762  1863585
# Yucca           0.829638   173152
#
# [76 rows x 2 columns]

# %% [markdown]
# # Find nutritional content for each food

# %%
pip install fooddatacentral
# Out:
# ...
#   Using cached fooddatacentral-1.0.10-py3-none-any.whl (6.8 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import fooddatacentral as fdc
import warnings
apikey = "Z4ehkkMbO1DlcukePiecqfxU55sRATGnDJHItl5B"
D = {}
count = 0
for food in df0.index:
    try:
        FDC = df0.loc[df0.index==food,'FDC'].iloc[0]
        D[food] = fdc.nutrients(apikey,FDC).Quantity
        print(food)
    except AttributeError:
        warnings.warn(f"Couldn't find FDC Code {FDC} for food {food}.")

D = pd.DataFrame(D,dtype=float)
# Out:
# Avocado
# Bananas
# Beans
# Beef
# Beef Entrails
# Beer
# Beets
# Bread (french)
# Bread (sliced)
# Bread (sweet)
# Cabbages
# Cakes
# Candies
# Carrots
# Celery
# Chayote
# Chicken
# Chicken Giblets
# Chilies
# Chocolate
# /srv/conda/lib/python3.9/site-packages/fooddatacentral/fooddatacentral.py:89: UserWarning:
#
# Some problem with request: <Response [400]>
#
# /tmp/ipykernel_157/1397216144.py:12: UserWarning:
#
# Couldn't find FDC Code <NA> for food Cigarettes.
# Coffee (instant)
# Cookies
# Cooking Oil
# Corn Flakes
# Corn Tamales
# Cornmeal
# Crema Fresca
# Cucumbers
# Dried Seeds
# Eggs
# Fish (Fresh)
# Garlic
# Granulated Sugar
# Herbs
# Ice Cream
# Incaparina
# Juice (Branded)
# Juices (Packaged)
# Lemons
# Lettuce
# /tmp/ipykernel_157/1397216144.py:12: UserWarning:
#
# Couldn't find FDC Code 2644263 for food Maize.
# Margarine
# Melons
# Milk
# Milk (powdered)
# Mineral Water
# Onions
# Oranges
# Other
# Other Atoles
# Other Sauces
# ...

# %%
nutrition_chart = D.fillna(0)
nutrition_chart
# Out:
#                                Avocado  Bananas  Beans  Beef  Beef Entrails  \
# Alanine                           0.00    0.222    0.0   0.0           0.00
# Alcohol, ethyl                    0.00    0.000    0.0   0.0           0.00
# Amino acids                       0.00    0.000    0.0   0.0           0.00
# Arginine                          0.00    0.176    0.0   0.0           0.00
# Ash                               0.00    3.020    0.0   0.0           0.00
# ...                                ...      ...    ...   ...            ...
# Vitamin K (Menaquinone-4)         0.00    0.000    0.0   0.0           0.00
# Vitamin K (phylloquinone)        96.70    2.000    0.0   0.0           6.30
# Vitamins and Other Components     0.00    0.000    0.0   0.0           0.00
# Water                            45.00    3.000    0.0   0.0          69.90
# Zinc, Zn                          0.25    0.610    0.0   0.0           4.52
#
# ...

# %%
sorted = df0.sort_values(by='beta',ascending=False)
sorted
# Out:
#                      beta      FDC
# j
# Juice (Branded)  1.666867  2340979
# Ice Cream        1.641413  2060018
# Bananas          1.557200   173945
# Candies          1.496632  2042913
# Sweets           1.449969  2345607
# ...                   ...      ...
# Other Sauces     0.656535  2341483
# Beans            0.620259  2169653
# Salt             0.565418  2120877
# Tortillas        0.409561  2092058
# Maize            0.060084  2644263
#
# [76 rows x 2 columns]

# %%
sorted.index = sorted.index.astype(str)

foods = sorted.index[:5].append(sorted.index[-5:])

valid_foods = [food for food in foods if food in nutrition_chart.columns]

print("Nutritional Content for the First and Last Five Foods in df0:")
nutrition_chart[valid_foods]
# Out:
# Nutritional Content for the First and Last Five Foods in df0:
#                                Juice (Branded)  Ice Cream  Bananas  Candies  \
# Alanine                                   0.00        0.0    0.222      0.0
# Alcohol, ethyl                            0.00        0.0    0.000      0.0
# Amino acids                               0.00        0.0    0.000      0.0
# Arginine                                  0.00        0.0    0.176      0.0
# Ash                                       0.00        0.0    3.020      0.0
# ...                                        ...        ...      ...      ...
# Vitamin K (Menaquinone-4)                 0.00        0.0    0.000      0.0
# Vitamin K (phylloquinone)                 6.10        0.0    2.000      0.0
# Vitamins and Other Components             0.00        0.0    0.000      0.0
# Water                                    87.60        0.0    3.000      0.0
# ...

# %%
df1 = nutrition_chart[valid_foods].copy()
df_filtered = df1[(df1 != 0).any(axis=1)]
df_filtered
# Out:
#                               Juice (Branded)  Ice Cream  Bananas  Candies  \
# Alanine                                  0.00        0.0    0.222      0.0
# Arginine                                 0.00        0.0    0.176      0.0
# Ash                                      0.00        0.0    3.020      0.0
# Aspartic acid                            0.00        0.0    0.503      0.0
# Calcium, Ca                             68.00       68.0   22.000      0.0
# ...                                       ...        ...      ...      ...
# Vitamin E (alpha-tocopherol)             0.73        0.0    0.390      0.0
# Vitamin E, added                         0.73        0.0    0.000      0.0
# Vitamin K (phylloquinone)                6.10        0.0    2.000      0.0
# Water                                   87.60        0.0    3.000      0.0
# Zinc, Zn                                 0.63        0.0    0.610      0.0
#
# ...
